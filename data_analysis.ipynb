# %%
import pandas as pd
from ast import literal_eval

# %%
df=pd.read_csv('data_analytics_clean.csv',converters={'states':literal_eval})
df['states'][0]
# Out:
# ['NM']

# %%
df['company'].value_counts().nlargest(10)
# Out:
# UnitedHealth Group    353
# Walmart               312
# Meta                  296
# TikTok                286
# Labcorp               259
# CVS Health            250
# Wells Fargo           240
# Amazon                237
# Avanade               218
# Lockheed Martin       200
# Name: company, dtype: int64

# %%
df[df['name']=='Data Engineer']
# Out:
#             id           name        states  levels          tags  \
# 782   10939927  Data Engineer  [MA, CA, NY]     mid           NaN
# 810   11260677  Data Engineer          [TX]  senior  Fortune 1000
# 893    7427119  Data Engineer      [Remote]     mid           NaN
# 1523  10939875  Data Engineer  [MA, CA, NY]     mid           NaN
# 1542  11129476  Data Engineer      [IL, GA]     mid           NaN
# 1695  11430905  Data Engineer          [TX]     mid           NaN
# 1897  11426562  Data Engineer      [Remote]  senior           NaN
# 1921  11427110  Data Engineer      [Remote]  senior           NaN
# 1945  11233343  Data Engineer          [MA]  senior           NaN
# 2207   7496239  Data Engineer          [TX]  senior           NaN
# 2253  11402327  Data Engineer          [MA]     mid           NaN
# 2493   9715944  Data Engineer      [Remote]  senior           NaN
# 2611  11426462  Data Engineer      [Remote]  senior           NaN
# ...
