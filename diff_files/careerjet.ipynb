# %%
#pip install careerjet-api==3.2
# Out:
# Collecting careerjet-api==3.2
#   Downloading careerjet_api-3.2-py3-none-any.whl (6.8 kB)
# Requirement already satisfied: requests in c:\users\shash\anaconda3\lib\site-packages (from careerjet-api==3.2) (2.26.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\shash\anaconda3\lib\site-packages (from requests->careerjet-api==3.2) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shash\anaconda3\lib\site-packages (from requests->careerjet-api==3.2) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\shash\anaconda3\lib\site-packages (from requests->careerjet-api==3.2) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shash\anaconda3\lib\site-packages (from requests->careerjet-api==3.2) (3.2)
# Installing collected packages: careerjet-api
# Successfully installed careerjet-api-3.2
# Note: you may need to restart the kernel to use updated packages.

# %%
#http://www.careerjet.com

#pydoc careerjet_api_client

# %%
from careerjet_api import CareerjetAPIClient

cj  =  CareerjetAPIClient("en_US");

result_json = cj.search({
                        'location'    : 'New Jersey',
                        'keywords'    : 'python',
                        'affid'       : '213e213hd12344552',
                        'user_ip'     : '11.22.33.44',
                        'url'         : 'http://www.careerjet.com/jobsearch?q=python&l=New Jersey',
                        'user_agent'  : 'Mozilla/5.0 (X11; Linux x86_64; rv:31.0) Gecko/20100101 Firefox/31.0'
                      });

# %%
import pprint as pp

result_json
# Out:
# {'jobs': [{'locations': 'Jersey City, NJ',
#    'site': '',
#    'date': 'Thu, 18 May 2023 07:18:01 GMT',
#    'url': 'https://jobviewtrack.com/en-us/job-4f12417d54100701495464061e0402081545066a390a5e4352432f200a1842184f130d136f5650154259/dffb9efaa2ab52709084ff232c9416c5.html?affid=213e213hd12344552',
#    'title': 'Python Developer',
#    'description': "Job Description  Genesis10 is currently seeking an <b>Python</b> Developer with our client in the financial industry located...:   3&plus; years' experience in <b>Python</b> or similar (e.g., C# or Java)  3&plus; years' experience in SQL Server or equivalent...",
#    'company': 'Genesis10',
#    'salary': ''},
#   {'locations': 'Jersey City, NJ',
#    'site': '',
#    'date': 'Wed, 17 May 2023 22:18:32 GMT',
#    'url': 'https://jobviewtrack.com/en-us/job-1a49417d54100701495464061e0402081545066a3b164b4849677e442b0b51114c0c18041c6535590000061d286f585b4808001e420622310d000d132f7375595c461c1a/b8228ddf54535841412585a94bc9e21e.html?affid=213e213hd12344552',
#    'title': 'Python Developer With Reactjs || Onsite - New Jersey ||',
#    'description': 'Hi   Hope you are doing well,  Urgent Opening For <b>Python</b> Developer with ReactJS role, if you are interested and a good... fit, feel free to reach me directly at or +1(609) 998-3431.   Role : <b>Python</b> Developer with ReactJS (Candidate with good...',
#    'company': 'Software Technology Inc',
#    'salary': ''},
#   {'locations': 'Jersey City, NJ',
#    'site': '',
#    'date': 'Wed, 17 May 2023 22:14:12 GMT',
#    'url': 'https://jobviewtrack.com/en-us/job-1912417d54100701497511565d575f/d174bfaa2998e409fc5ec7645d1d30c0.html?affid=213e213hd12344552',
#    'title': 'Python with Airflow',
#    'description': '<b>Python</b> Developer with Airflow   Client - BNYM   Imp - Altimetric   Yrs. of Exp - 10+   Location NJ/NY Day 1 Onsite...   Note: Need USC, GC, H1 T only   Job Description:   <b>Python</b>, Jupiter hub, airflow, Java   Database knowledge - Oracle / SQL...',
#    'company': 'Soft Snippets',
#    'salary': ''},
#   {'salary_min': '120000',
#    'locations': 'Jersey City, NJ',
#    'salary_type': 'Y',
#    'date': 'Wed, 17 May 2023 22:04:35 GMT',
#    'description': ' user requirements.  Design, code, test, and debug software applications using VBA, SQL, and <b>Python</b>.  Participate in the..., and <b>Python</b>.  Solid understanding of software development principles and best practices.  Experience with the full software...',
#    'salary_currency_code': 'USD',
#    'salary': '$120000 - 130000 per year',
#    'site': '',
#    'url': 'https://jobviewtrack.com/en-us/job-1c4f417e42021b19460645432c041802094f040d1b53797a712f7e0b091a5015520648250b11004c1b180c0128786c610d200a1842184f130d136c371c541c0707536e4e4b48410b1f0b5576762129413d362921455d5c451b/97d7b7252b92c09b4bb3799d9f78c67c.html?affid=213e213hd12344552',
#    'title': 'Software Developer | VBA,PYTHON,SQL | HYBRID | FT | USC/GC',
#    'salary_max': '130000',
#    'company': 'Sciprex'},
#   {'locations': 'Newark, NJ',
#    'site': '',
#    'date': 'Wed, 17 May 2023 07:52:42 GMT',
#    'url': 'https://jobviewtrack.com/en-us/job-131d416c7a374f3e5e00480c06412a0213451807191658296d54590c0000073045150d0d0117005276293e200a6f585b4808001e42062233111506080b00353f3a716b7c6e0d6c333c6f1641165b5d/979b636eae5ac7b0d2395d18d364c23d.html?affid=213e213hd12344552',
#    'title': 'AWS Python Developer',
#    'description': ' of professional experience as a Back-End Developer in an enterprise environment utilizing <b>Python</b> and Pandas.   - Minimum of 2+ years...',
#    'company': 'Insight Global',
#    'salary': ''},
#   {'locations': 'Newark, NJ',
#    'site': '',
#    'date': 'Wed, 17 May 2023 07:42:15 GMT',
#    'url': 'https://jobviewtrack.com/en-us/job-1c4d417d54100701495464061e0402081545066a390a5e4352432f200a1842184f130d136f5650164c5d/b04877be4cc278eaed84d8bed3d21c53.html?affid=213e213hd12344552',
#    'title': 'Python Developer',
#    'description': ' experience in software design and development.   - 1-3 years of Data experience at a technical level   - Knowledge of <b>Python</b>...',
#    'company': 'Insight Global',
#    'salary': ''},
#   {'locations': 'Jersey City, NJ',
#    'site': '',
#    'date': 'Wed, 17 May 2023 07:30:42 GMT',
#    'url': 'https://jobviewtrack.com/en-us/job-1a4d417e42021b19460645432d0f090e0b45111a4923535f554243663c01410057021a044e220b471d060c1658296d54590c000007314e04010f0b02172224111d1b45451d7e42021b19460645612d0f090e0b45111a68421f1e0b1c/dd445377df4a3904e643f420c66cf035.html?affid=213e213hd12344552',
#    'title': 'Software Engineer (Python)',
#    'description': ', and foreign exchange securities, preferred.  5+ years of software development experience with <b>Python</b>. The candidate must be a self...',
#    'company': 'Insight Global',
#    'salary': ''},
#   {'locations': 'Iselin, NJ',
#    'site': '',
#    'date': 'Wed, 17 May 2023 04:10:37 GMT',
#    'url': 'https://jobviewtrack.com/en-us/job-4f1241694c100e4e621a470a06040b1567700d1c011c440b78434a0d010b42062233111506080b0030091d12286e534a440a0a0b5576701a1c0901096411415d5c46/c8d760667b2861876e3f88aa7fb0b234.html?affid=213e213hd12344552',
#    'title': 'Python Data Engineer',
#    'description': '   Job Description   Proficiency in languages like <b>Python</b> and some understanding of R.   Proficiency in Bigdata frameworks for processing large... solutions and data lakes.   Feature Engineering   Data Visualization skills using <b>python</b> libraries.   Job workflow orchestration...',
#    'company': 'Han Staffing',
#    'salary': ''},
#   {'locations': 'Jersey City, NJ',
#    'site': '',
#    'date': 'Tue, 16 May 2023 22:33:24 GMT',
#    'url': 'https://jobviewtrack.com/en-us/job-4f12417d54100701495464061e0402081545066a390a5e4352432f200a1842184f130d136f5650154259/fd0251d9812feff2b1d4c3edca8bdb3c.html?affid=213e213hd12344552',
#    'title': 'Python Developer',
#    'description': "Job Title: <b>Python</b> Developer   Location Jersey City, NJ   Must-Haves:    Bachelor's degree in computer science... programming with <b>Python</b> 3 and Django  Experience of automation of code deployment through the use of containers  Docker/Podman...",
#    'company': 'VITATECH INC',
#    'salary': ''},
#   {'locations': 'Jersey City, NJ',
#    'site': '',
#    'date': 'Tue, 16 May 2023 22:14:21 GMT',
#    'url': 'https://jobviewtrack.com/en-us/job-4f12417d54100701495464061e0402081545066a390a5e4352432f200a1842184f130d136f5650154259/d4592ccedd682519568a28b8430e835d.html?affid=213e213hd12344552',
#    'title': 'Python Developer',
#    'description': '<b>Python</b> Developer   Location-Boston MA   12+Months   Job Description   Strong <b>Python</b> Programming Skills using OOPS... concepts, test scripts/content development using <b>Python</b>. Strong Test automation and framework development/usage experience...',
#    'company': 'SysMind',
#    'salary': ''},
#   {'salary_min': '128250',
#    'locations': 'Jersey City, NJ',
#    'salary_type': 'Y',
#    'date': 'Mon, 15 May 2023 22:54:42 GMT',
#    'description': ' assessments  Deep knowledge of one specific infrastructure technology and scripting languages (e.g., Scripting, <b>Python</b>...  Experienced in scripting languages, SQL and <b>Python</b>  Knowledge of ETL tools  Knowledge of BI tools like Tableau    JPMorgan Chase...',
#    'salary_currency_code': 'USD',
#    'salary': '$128250 - 180000 per year',
#    'site': '',
#    'url': 'https://jobviewtrack.com/en-us/job-1e1241694c100e4e621a470a06040b156764151c0853674a534c4a01020b490022301d111e081754542d0714434558485f662600410641101c131b041155060d4936444c544348011d6c6b114107482400000c4e110d1b721b1e081b1c/90a4b4daaa8f826239f40b4f463b99bf.html?affid=213e213hd12344552',
#    'title': 'Lead Infrastructure Engineer- Data Management Support -Python',
#    'salary_max': '180000',
#    'company': 'JPMorgan Chase'},
#   {'salary_min': '137750',
#    'locations': 'Jersey City, NJ',
#    'salary_type': 'Y',
#    'date': 'Mon, 15 May 2023 22:21:12 GMT',
#    'description': ' languages, ideally including one of Go, <b>Python</b>, React, Java,  Experience working with modern private & public cloud...',
#    'salary_currency_code': 'USD',
#    'salary': '$137750 - 200000 per year',
#    'site': '',
#    'url': 'https://jobviewtrack.com/en-us/job-4c1b416148050b4e741b46171f001c0245651a0f001d4f4e4f2f7e0b091a50155206482400000c4e110d1b537a524945420a6d3e5e00480c06412f30360031060e1a444e585f2f370008530341110d412b0902491a0d0c01286a6a7e0d2101094e1a45061a605f52501645/f40a8577fd8c145bb5cb7e9e5beeb2b2.html?affid=213e213hd12344552',
#    'title': 'Lead Software Engineer -Python ,AWS',
#    'salary_max': '200000',
#    'company': 'JPMorgan Chase'},
#   {'salary_min': '137750',
#    'locations': 'Jersey City, NJ',
#    'salary_type': 'Y',
#    'date': 'Sun, 14 May 2023 22:46:14 GMT',
#    'description': '  Experience with PL-SQL & Oracle database  Experience with <b>Python</b> script, Multi-threaded programming and Memory management...',
#    'salary_currency_code': 'USD',
#    'salary': '$137750 - 200000 per year',
#    'site': '',
#    'url': 'https://jobviewtrack.com/en-us/job-1918416148050b4e741b46171f001c0245651a0f001d4f4e4f2f7e0b091a50155206482400000c4e110d1b537a524945420a6d3d4812541409130b47204e130107164f593f6148050b4e621a470a06040b1567700d1c011c440b78434a0d010b420621525d545856/a1b7132e83b7136b76a2ce8737a7e8c6.html?affid=213e213hd12344552',
#    'title': 'Lead Software Engineer - Python',
#    'salary_max': '200000',
#    'company': 'JPMorgan Chase'},
#   {'salary_min': '137750',
#    'locations': 'Jersey City, NJ',
#    'salary_type': 'Y',
#    'date': 'Sun, 14 May 2023 22:15:10 GMT',
#    'description': ', multi-agent systems (MAS), computational game theory, natural language processing (NLP)  <b>Python</b> coding  Masters degree in...',
#    'salary_currency_code': 'USD',
#    'salary': '$137750 - 200000 per year',
#    'site': '',
#    'url': 'https://jobviewtrack.com/en-us/job-1918416148050b4e741b46171f001c0245651a0f001d4f4e4f2f7e0b091a50155206482400000c4e110d1b537a524945420a6d3d4812541409130b47204e130107164f593f6148050b4e621a470a06040b1567700d1c011c440b78434a0d010b420621525d545856/ce396216b9ea3d59982dd8e3f5494547.html?affid=213e213hd12344552',
#    'title': 'Python Lead Software Engineer - Conversational AI',
#    'salary_max': '200000',
#    'company': 'JPMorgan Chase'},
#   {'salary_min': '123500',
#    'locations': 'Jersey City, NJ',
#    'salary_type': 'Y',
#    'date': 'Sun, 14 May 2023 22:02:32 GMT',
#    'description': '.   As a <b>Python</b> AWS Software Engineer III at JPMorgan Chase within the Corporate Sector Jade Customer Success , you serve... with code coverage in Junit / <b>Python</b> + pytest + pypi  Hands-on experience with Cloud Services - AWS services  Big Data hands...',
#    'salary_currency_code': 'USD',
#    'salary': '$123500 - 180000 per year',
#    'site': '',
#    'url': 'https://jobviewtrack.com/en-us/job-1b4a417e42021b19460645432d0f090e0b45111a4923535f554243663f17531c4f0d4820393445651a0f001d4f4e4f2f7e0b091a50155206482400000c4e110d1b716b7c6e0d680a0807491145116a3117130d4f1a482c1d4d42534848166e5f12411652/b606e01288a07710b0c2360896f8bdda.html?affid=213e213hd12344552',
#    'title': 'Python AWS Software Engineer III',
#    'salary_max': '180000',
#    'company': 'JPMorgan Chase'},
#   {'locations': 'Jersey City, NJ',
#    'site': '',
#    'date': 'Sat, 13 May 2023 05:35:10 GMT',
#    'url': 'https://jobviewtrack.com/en-us/job-121a417d541007014976660a060000040c41186a38064b5949572c555a5b1145/efcf3ab667a8565aec88f845cca6dcfd.html?affid=213e213hd12344552',
#    'title': 'Python/Quartz/OO/Financial/JC',
#    'description': ' for designing and developing web-based <b>Python</b> solutions to help solve complex business problems within one of the most interesting...:   Strong knowledge of <b>Python</b>, Object Oriented programming  Experience with relational database/SQL, CI/CD tools such as Git, Jenkins...',
#    'company': 'Genesis10',
#    'salary': ''},
#   {'salary_min': '100000',
#    'locations': 'New Jersey',
#    'salary_type': 'Y',
#    'date': 'Sat, 13 May 2023 01:20:05 GMT',
#    'description': "+ Years' Experience  Experience with Azure, Snowflake, <b>Python</b>, Architecture (design aspect)  Experience with Azure Data...",
#    'salary_currency_code': 'USD',
#    'salary': '$100000 - 130000 per year',
#    'site': '',
#    'url': 'https://jobviewtrack.com/en-us/job-1f1f416c57111d0b0730411709412b0902491a0d0c01286f5c594c442a00401d4e060d134e35004d1b1c0c716e4a494c0d2101094e1a45061a633c02084f000d4923535f554243663d0b4a1b5406482400000c4e110d1b7219120e/1806b5e851d7dfb67eeec22c969ce972.html?affid=213e213hd12344552',
#    'title': 'Lead Data Engineer (Azure, Snowflake, Python) - Remote',
#    'salary_max': '130000',
#    'company': 'ZenQ'},
#   {'locations': 'Jersey City, NJ',
#    'site': '',
#    'date': 'Sat, 13 May 2023 00:54:55 GMT',
#    'url': 'https://jobviewtrack.com/en-us/job-121a417d541007014976660a060000040c41186a38064b5949572c555a5b1145/2448af32df7b3ac54b5ac9f7c82cfb2f.html?affid=213e213hd12344552',
#    'title': 'Python/Quartz/OO/Financial/JC',
#    'description': ' broader development community to hold high standards for quality software delivery    Requirements:   <b>Python</b>/Quartz  SQL...',
#    'company': 'Genesis10',
#    'salary': ''},
#   {'locations': 'Jersey City, NJ',
#    'site': '',
#    'date': 'Sat, 13 May 2023 00:15:50 GMT',
#    'url': 'https://jobviewtrack.com/en-us/job-1b4a417e42021b19460645432d0f090e0b45111a4923535f554243663f17531c4f0d4820393445651a0f001d4f4e4f2f7e0b091a50155206482400000c4e110d1b716b7c6e0d680a0807491145116a3117130d4f1a482c1d4d42534848166e5f12411652/63a3f2a99af31102e558513ffd1c1166.html?affid=213e213hd12344552',
#    'title': 'Python AWS Software Engineer III',
#    'description': ' to the next level.   As a <b>Python</b> AWS Software Engineer III at JPMorgan Chase within the Corporate Sector Jade Customer... with writing unit tests with code coverage in Junit / <b>Python</b> + pytest + pypi  Hands-on experience with Cloud Services - AWS...',
#    'company': 'JPMorgan Chase',
#    'salary': ''},
#   {'locations': 'Jersey City, NJ',
#    'site': '',
#    'date': 'Fri, 12 May 2023 22:41:00 GMT',
#    'url': 'https://jobviewtrack.com/en-us/job-1818417f48050c1a073e73432c041802094f040d1b717a524945420a4f2a4202450f07110b15677211090a070a6f585b4808001e420622310d000d13456a276a23200a6f585b4808001e420621525d545856/bfdaf26afe822ec2a003622798792ac5.html?affid=213e213hd12344552',
#    'title': 'Python Developer (React.JS)',
#    'description': 'Greetings ,   Hope you are doing great,   We at Software Technology Inc. hiring for an <b>Python</b> Developer role..., if you are interested and a good fit, feel free to reach me directly.   Role <b>Python</b> Developer with ReactJS (Candidate with good coding...',
#    'company': 'Software Technology Inc',
#    'salary': ''}],
#  'hits': 3649,
#  'response_time': 0.113436222076416,
#  'type': 'JOBS',
#  'pages': 183}
